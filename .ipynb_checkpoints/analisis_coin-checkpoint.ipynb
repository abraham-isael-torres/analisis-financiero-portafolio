# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Descargar datos históricos, ej. Coinbase (COIN)
data = yf.download("COIN", start="2024-01-01", end="2026-07-26")

# Graficar el precio de cierre
plt.figure(figsize=(10, 5))
plt.plot(data.index, data["Close"], label="COIN - Precio de cierre")
plt.title("Precio histórico de COIN")
plt.xlabel("Fecha")
plt.ylabel("Precio (USD)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Retornos diarios y volatilidad anualizada
data["Retorno"] = data["Close"].pct_change()
volatilidad_anual = data["Retorno"].std() * (252 ** 0.5)
print(f"Volatilidad anualizada: {volatilidad_anual:.2%}")
# Out:
# Volatilidad anualizada: 78.51%

# %%
# Volatilidad móvil de 30 días, anualizada
data["Vol_30d"] = data["Retorno"].rolling(window=30).std() * (252 ** 0.5)

plt.figure(figsize=(10, 5))
plt.plot(data.index, data["Vol_30d"])
plt.title("Volatilidad rodante (30 días) - COIN")
plt.xlabel("Fecha")
plt.ylabel("Volatilidad anualizada")
plt.grid(True)
plt.show()
acumulado = (1 + data["Retorno"]).cumprod()
maximo_historico = acumulado.cummax()
drawdown = (acumulado - maximo_historico) / maximo_historico

max_drawdown = drawdown.min()
print(f"Máximo drawdown: {max_drawdown:.2%}")
# Out:
# Máximo drawdown: -66.39%

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Descargar los tres activos: COIN, S&P 500 (vía ETF SPY), y Bitcoin
tickers = ["COIN", "SPY", "BTC-USD"]
datos = yf.download(tickers, start="2024-01-01", end="2026-07-26")["Close"]

datos.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
# Ticker           BTC-USD        COIN         SPY
# Date
# 2024-01-01  44167.332031         NaN         NaN
# 2024-01-02  44957.968750  156.880005  458.809143
# 2024-01-03  42848.175781  152.240005  455.062286
# 2024-01-04  44179.921875  155.600006  453.596436
# 2024-01-05  44162.691406  153.979996  454.217712

# %%
# Retornos diarios de cada activo
retornos = datos.pct_change()

# Drawdown para cada columna
acumulado = (1 + retornos).cumprod()
maximo_historico = acumulado.cummax()
drawdown = (acumulado - maximo_historico) / maximo_historico

# Máximo drawdown de cada activo
print("Máximo drawdown por activo:")
print(drawdown.min())
# Out:
# Máximo drawdown por activo:
# Ticker
# BTC-USD   -0.530600
# COIN      -0.748401
# SPY       -0.172057
# dtype: float64

# %%
plt.figure(figsize=(12, 6))
for activo in tickers:
    plt.plot(drawdown.index, drawdown[activo], label=activo)

plt.title("Comparación de Drawdown: COIN vs S&P 500 vs Bitcoin")
plt.xlabel("Fecha")
plt.ylabel("Drawdown")
plt.legend()
plt.grid(True)
plt.axhline(0, color="black", linewidth=0.8)
plt.savefig("drawdown_comparativo.png", dpi=150, bbox_inches="tight")
plt.show()
